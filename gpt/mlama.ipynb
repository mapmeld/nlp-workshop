# %% [markdown]
# Large Language Models (LLMs) learn which words go together, and also pick up on facts. For example, given the prompt "The United Nations headquarters is in __" or "Manila is the capital of _", GPT-2 has knowledge of the answer.
#
# Facebook/Meta developed a benchmark named LAMA (LAnguage Model Analysis), which generates factual sentences in English language. These sentences are templates with the format "{x} was born in {y}" and the template code can replace {x}, {y}, or both. In this case, a left-to-right generative model can more easily replace {y}. https://github.com/facebookresearch/LAMA
#
# Researchers at LMU Munich created a multilingual version of the benchmark (mLAMA) in 2021.  Template sentences are available in multiple languages and filled in with WikiData. https://github.com/norakassner/mlama
#
# In this workshop (created for ML Prague) this is documentation showing how I filled Czech language templates.

# %%
# https://github.com/conda-incubator/condacolab
! pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:30
# 🔁 Restarting kernel...

# %%
! pip uninstall -y overrides
! pip install overrides==3.1.0
# Out:
# Found existing installation: overrides 6.1.0
# Uninstalling overrides-6.1.0:
#   Successfully uninstalled overrides-6.1.0
# Collecting overrides==3.1.0
#   Using cached overrides-3.1.0-py3-none-any.whl
# Installing collected packages: overrides
# Successfully installed overrides-3.1.0

# %%
# %%capture
! rm -rf mlama
! rm -rf LAMA
! git clone https://github.com/norakassner/mlama
! git clone https://github.com/facebookresearch/LAMA

# %%
! conda create -n lama37 -y python=3.7 && conda activate lama37
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/lama37
#
#   added / updated specs:
#     - python=3.7
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   ca-certificates    conda-forge/linux-64::ca-certificates-2021.10.8-ha878542_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.36.1-hea4e1c9_2
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-12.1.0-h8d9b700_16
#   libgomp            conda-forge/linux-64::libgomp-12.1.0-h8d9b700_16
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-12.1.0-ha89aaad_16
#   libzlib            conda-forge/linux-64::libzlib-1.2.11-h166bdaf_1014
#   ncurses            conda-forge/linux-64::ncurses-6.3-h27087fc_1
#   openssl            conda-forge/linux-64::openssl-3.0.3-h166bdaf_0
#   pip                conda-forge/noarch::pip-22.1-pyhd8ed1ab_0
#   python             conda-forge/linux-64::python-3.7.12-hf930737_100_cpython
#   python_abi         conda-forge/linux-64::python_abi-3.7-2_cp37m
#   readline           conda-forge/linux-64::readline-8.1-h46c0cb4_0
#   setuptools         conda-forge/linux-64::setuptools-62.3.1-py37h89c1867_0
#   sqlite             conda-forge/linux-64::sqlite-3.38.5-h4ff8645_0
#   tk                 conda-forge/linux-64::tk-8.6.12-h27826a3_0
#   wheel              conda-forge/noarch::wheel-0.37.1-pyhd8ed1ab_0
#   xz                 conda-forge/linux-64::xz-5.2.5-h516909a_1
#   zlib               conda-forge/linux-64::zlib-1.2.11-h166bdaf_1014
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate lama37
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
! conda create -n mlama -y python=3.7 && conda activate mlama
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/mlama
#
#   added / updated specs:
#     - python=3.7
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   ca-certificates    conda-forge/linux-64::ca-certificates-2021.10.8-ha878542_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.36.1-hea4e1c9_2
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-12.1.0-h8d9b700_16
#   libgomp            conda-forge/linux-64::libgomp-12.1.0-h8d9b700_16
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-12.1.0-ha89aaad_16
#   libzlib            conda-forge/linux-64::libzlib-1.2.11-h166bdaf_1014
#   ncurses            conda-forge/linux-64::ncurses-6.3-h27087fc_1
#   openssl            conda-forge/linux-64::openssl-3.0.3-h166bdaf_0
#   pip                conda-forge/noarch::pip-22.1-pyhd8ed1ab_0
#   python             conda-forge/linux-64::python-3.7.12-hf930737_100_cpython
#   python_abi         conda-forge/linux-64::python_abi-3.7-2_cp37m
#   readline           conda-forge/linux-64::readline-8.1-h46c0cb4_0
#   setuptools         conda-forge/linux-64::setuptools-62.3.1-py37h89c1867_0
#   sqlite             conda-forge/linux-64::sqlite-3.38.5-h4ff8645_0
#   tk                 conda-forge/linux-64::tk-8.6.12-h27826a3_0
#   wheel              conda-forge/noarch::wheel-0.37.1-pyhd8ed1ab_0
#   xz                 conda-forge/linux-64::xz-5.2.5-h516909a_1
#   zlib               conda-forge/linux-64::zlib-1.2.11-h166bdaf_1014
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate mlama
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
! cd mlama && pip install -r requirements.txt
# Out:
# Collecting Cython==0.29.2
#   Downloading Cython-0.29.2-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 4.0 MB/s
# Collecting numpy==1.15.1
#   Downloading numpy-1.15.1-cp37-cp37m-manylinux1_x86_64.whl (13.8 MB)
#      |████████████████████████████████| 13.8 MB 22.2 MB/s
# Collecting torch==1.0.1
#   Downloading torch-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (560.1 MB)
#      |████████████████████████████████| 560.1 MB 23 kB/s
# Collecting pytorch-pretrained-bert==0.6.1
#   Downloading pytorch_pretrained_bert-0.6.1-py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 55.2 MB/s
# Collecting allennlp==0.8.5
#   Downloading allennlp-0.8.5-py3-none-any.whl (7.4 MB)
#      |████████████████████████████████| 7.4 MB 50.4 MB/s
# Collecting spacy==2.1.8
#   Downloading spacy-2.1.8-cp37-cp37m-manylinux1_x86_64.whl (30.8 MB)
#      |████████████████████████████████| 30.8 MB 84.5 MB/s
# Collecting tqdm==4.26.0
#   Downloading tqdm-4.26.0-py2.py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.7 MB/s
# Collecting termcolor==1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting pandas==0.23.4
#   Downloading pandas-0.23.4-cp37-cp37m-manylinux1_x86_64.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 42.2 MB/s
# Collecting fairseq==0.8.0
#   Downloading fairseq-0.8.0.tar.gz (216 kB)
#      |████████████████████████████████| 216 kB 54.2 MB/s
# Collecting colorama==0.4.1
#   Downloading colorama-0.4.1-py2.py3-none-any.whl (15 kB)
# Collecting scipy==1.3.2
#   Downloading scipy-1.3.2-cp37-cp37m-manylinux1_x86_64.whl (25.2 MB)
#      |████████████████████████████████| 25.2 MB 62.0 MB/s
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 83.7 MB/s
# Collecting overrides
#   Downloading overrides-6.1.0-py3-none-any.whl (14 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Collecting responses>=0.7
#   Downloading responses-0.20.0-py3-none-any.whl (27 kB)
# Collecting h5py
#   Downloading h5py-3.6.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 51.2 MB/s
# Collecting conllu==1.3.1
#   Downloading conllu-1.3.1-py2.py3-none-any.whl (9.3 kB)
# Collecting pytest
#   Downloading pytest-7.1.2-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 57.5 MB/s
# Collecting pytorch-transformers==1.1.0
#   Downloading pytorch_transformers-1.1.0-py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 57.7 MB/s
# Collecting tensorboardX>=1.2
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 59.8 MB/s
# Requirement already satisfied: requests>=2.18 in /usr/local/lib/python3.7/site-packages (from allennlp==0.8.5->-r requirements.txt (line 5)) (2.25.1)
# Collecting sqlparse>=0.2.4
#   Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 857 kB/s
# Collecting word2number>=1.1
#   Downloading word2number-1.1.zip (9.7 kB)
# Collecting pytz>=2017.3
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 47.9 MB/s
# Collecting jsonnet>=0.10.0
#   Downloading jsonnet-0.18.0.tar.gz (592 kB)
#      |████████████████████████████████| 592 kB 66.6 MB/s
# Collecting gevent>=1.3.6
#   Downloading gevent-21.12.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 41.9 MB/s
# Collecting numpydoc>=0.8.0
#   Downloading numpydoc-1.3.1-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 406 kB/s
# Collecting flask-cors>=3.0.7
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 23.5 MB/s
# Collecting matplotlib>=2.2.3
#   Downloading matplotlib-3.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 46.8 MB/s
# Collecting boto3
#   Downloading boto3-1.23.2-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 68.0 MB/s
# Collecting editdistance
#   Downloading editdistance-0.6.0-cp37-cp37m-manylinux2010_x86_64.whl (285 kB)
#      |████████████████████████████████| 285 kB 68.2 MB/s
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.7 MB/s
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 61.8 MB/s
# Collecting flaky
#   Downloading flaky-3.7.0-py2.py3-none-any.whl (22 kB)
# Collecting parsimonious>=0.8.0
#   Downloading parsimonious-0.9.0.tar.gz (48 kB)
#      |████████████████████████████████| 48 kB 5.3 MB/s
# Collecting flask>=1.0.2
#   Downloading Flask-2.1.2-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 3.3 MB/s
# Requirement already satisfied: cffi in /usr/local/lib/python3.7/site-packages (from fairseq==0.8.0->-r requirements.txt (line 10)) (1.14.5)
# Collecting fastBPE
#   Downloading fastBPE-0.1.0.tar.gz (35 kB)
# Collecting regex
#   Downloading regex-2022.4.24-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (749 kB)
#      |████████████████████████████████| 749 kB 59.6 MB/s
# Collecting sacrebleu
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 9.9 MB/s
# Collecting python-dateutil>=2.5.0
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 71.9 MB/s
# Collecting plac<1.0.0,>=0.9.6
#   Downloading plac-0.9.6-py2.py3-none-any.whl (20 kB)
# Collecting thinc<7.1.0,>=7.0.8
#   Downloading thinc-7.0.8-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 40.9 MB/s
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.7-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting blis<0.3.0,>=0.2.2
#   Downloading blis-0.2.4-cp37-cp37m-manylinux1_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 45.4 MB/s
# Collecting wasabi<1.1.0,>=0.2.0
#   Downloading wasabi-0.9.1-py3-none-any.whl (26 kB)
# Collecting srsly<1.1.0,>=0.0.6
#   Downloading srsly-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (184 kB)
#      |████████████████████████████████| 184 kB 59.7 MB/s
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35 kB)
# Collecting preshed<2.1.0,>=2.0.1
#   Downloading preshed-2.0.1-cp37-cp37m-manylinux1_x86_64.whl (82 kB)
#      |████████████████████████████████| 82 kB 366 kB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 43.2 MB/s
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.1.2-py3-none-any.whl (224 kB)
#      |████████████████████████████████| 224 kB 59.4 MB/s
# Collecting click>=8.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 5.5 MB/s
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 57.2 MB/s
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting importlib-metadata>=3.6.0
#   Downloading importlib_metadata-4.11.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: Six in /usr/local/lib/python3.7/site-packages (from flask-cors>=3.0.7->allennlp==0.8.5->-r requirements.txt (line 5)) (1.15.0)
# Collecting greenlet<2.0,>=1.1.0
#   Downloading greenlet-1.1.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (150 kB)
#      |████████████████████████████████| 150 kB 64.0 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from gevent>=1.3.6->allennlp==0.8.5->-r requirements.txt (line 5)) (49.6.0.post20210108)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 59.0 MB/s
# Collecting zope.event
#   Downloading zope.event-4.5.0-py2.py3-none-any.whl (6.8 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-4.2.0-py3-none-any.whl (24 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.8.0-py3-none-any.whl (5.4 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      |████████████████████████████████| 930 kB 56.6 MB/s
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 50.0 MB/s
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting matplotlib>=2.2.3
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 41.7 MB/s
#   Downloading matplotlib-3.5.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 22.5 MB/s
#   Downloading matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 43.0 MB/s
#   Downloading matplotlib-3.4.2-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 24.1 MB/s
#   Downloading matplotlib-3.4.1-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 981 kB/s
#   Downloading matplotlib-3.4.0-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 51.1 MB/s
#   Downloading matplotlib-3.3.4-cp37-cp37m-manylinux1_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 39.6 MB/s
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 7.3 MB/s
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 50.5 MB/s
# Collecting sphinx>=3.0
#   Downloading Sphinx-4.5.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 41.7 MB/s
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.18->allennlp==0.8.5->-r requirements.txt (line 5)) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.18->allennlp==0.8.5->-r requirements.txt (line 5)) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.18->allennlp==0.8.5->-r requirements.txt (line 5)) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests>=2.18->allennlp==0.8.5->-r requirements.txt (line 5)) (4.0.0)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 9.0 MB/s
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 8.6 MB/s
# Collecting packaging
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.4 MB/s
# Collecting imagesize
#   Downloading imagesize-1.3.0-py2.py3-none-any.whl (5.2 kB)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.3 MB/s
# Collecting docutils<0.18,>=0.14
#   Downloading docutils-0.17.1-py2.py3-none-any.whl (575 kB)
#      |████████████████████████████████| 575 kB 60.1 MB/s
# Collecting Pygments>=2.0
#   Downloading Pygments-2.12.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 38.4 MB/s
# Collecting babel>=1.3
#   Downloading Babel-2.10.1-py3-none-any.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 50.5 MB/s
# Collecting sphinxcontrib-serializinghtml>=1.1.5
#   Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 2.4 MB/s
# Collecting snowballstemmer>=1.1
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 985 kB/s
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 47.1 MB/s
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Collecting protobuf>=3.8.0
#   Downloading protobuf-3.20.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 40.8 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.0-py3-none-any.whl (23 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.8 MB/s
# Collecting botocore<1.27.0,>=1.26.2
#   Downloading botocore-1.26.2-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 48.2 MB/s
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/site-packages (from cffi->fairseq==0.8.0->-r requirements.txt (line 10)) (2.20)
# Collecting wcwidth>=0.2.5
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Collecting joblib
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      |████████████████████████████████| 306 kB 65.8 MB/s
# Collecting typing-utils>=0.0.3
#   Downloading typing_utils-0.1.0-py3-none-any.whl (10 kB)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting tomli>=1.0.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting attrs>=19.2.0
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 7.1 MB/s
# Collecting py>=1.8.2
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 8.0 MB/s
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Collecting tabulate>=0.8.9
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting sacrebleu
#   Downloading sacrebleu-1.5.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.7 MB/s
# Collecting portalocker==2.0.0
#   Downloading portalocker-2.0.0-py2.py3-none-any.whl (11 kB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Building wheels for collected packages: fairseq, termcolor, jsonnet, parsimonious, word2number, fastBPE
#   Building wheel for fairseq (setup.py) ... done
#   Created wheel for fairseq: filename=fairseq-0.8.0-cp37-cp37m-linux_x86_64.whl size=366342 sha256=d5ad11012440341d0cd22fa632e02e1b2308ad04f9b203212676130e53fff86c
#   Stored in directory: /root/.cache/pip/wheels/92/ca/98/a6dbc73762642643071bffa9376e74817b9cf09cafc22c75ad
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=4605570b46c4bcff83cc5bd6e1de85950add5d3e39857ed652ef4e9de714e1d4
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.18.0-cp37-cp37m-linux_x86_64.whl size=4001884 sha256=b85634b9a118f3b07f63f454ab9409971016103acd6e285558058e7b2139c2ff
#   Stored in directory: /root/.cache/pip/wheels/a9/63/f9/a653f9c21575e6ff271ee6a49939aa002005174cea6c35919d
#   Building wheel for parsimonious (setup.py) ... done
#   Created wheel for parsimonious: filename=parsimonious-0.9.0-py3-none-any.whl size=44298 sha256=9529f3708dc0218dfa3834615409a256974cced91c0206217df4cab3d6443dbc
#   Stored in directory: /root/.cache/pip/wheels/a4/54/88/c1ee7de0eabd1fb817cbf35824e4c2cba664d5816ddc64efb1
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5586 sha256=e4f35e1bdddb670c3ec1bbb8bbe5dcc60de69113b1cdc65011e131ef0e8973f0
#   Stored in directory: /root/.cache/pip/wheels/4b/c3/77/a5f48aeb0d3efb7cd5ad61cbd3da30bbf9ffc9662b07c9f879
#   Building wheel for fastBPE (setup.py) ... done
#   Created wheel for fastBPE: filename=fastBPE-0.1.0-cp37-cp37m-linux_x86_64.whl size=477362 sha256=2c6392d616d3fcbff8e0b1856be40be1ee1bfd500f49cea475313d48db8e6954
#   Stored in directory: /root/.cache/pip/wheels/bd/d4/0e/0d317a65f77d3f8049fedd8a2ee0519164cf3e6bd77ef886f1
# Successfully built fairseq termcolor jsonnet parsimonious word2number fastBPE
# Installing collected packages: zipp, typing-extensions, python-dateutil, jmespath, pytz, pyparsing, numpy, MarkupSafe, importlib-metadata, cymem, botocore, Werkzeug, wasabi, tqdm, srsly, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, s3transfer, Pygments, preshed, plac, packaging, murmurhash, Jinja2, itsdangerous, imagesize, docutils, click, blis, babel, alabaster, zope.interface, zope.event, wcwidth, typing-utils, torch, tomli, threadpoolctl, thinc, sphinx, sentencepiece, scipy, regex, py, protobuf, portalocker, pluggy, pillow, kiwisolver, joblib, iniconfig, greenlet, flask, cycler, cached-property, boto3, attrs, word2number, unidecode, tensorboardX, sqlparse, spacy, scikit-learn, sacrebleu, responses, pytorch-transformers, pytorch-pretrained-bert, pytest, parsimonious, overrides, numpydoc, nltk, matplotlib, jsonpickle, jsonnet, h5py, gevent, ftfy, flask-cors, flaky, fastBPE, editdistance, conllu, termcolor, pandas, fairseq, Cython, colorama, allennlp
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.59.0
#     Uninstalling tqdm-4.59.0:
#       Successfully uninstalled tqdm-4.59.0
# Successfully installed Cython-0.29.2 Jinja2-3.1.2 MarkupSafe-2.1.1 Pygments-2.12.0 Werkzeug-2.1.2 alabaster-0.7.12 allennlp-0.8.5 attrs-21.4.0 babel-2.10.1 blis-0.2.4 boto3-1.23.2 botocore-1.26.2 cached-property-1.5.2 click-8.1.3 colorama-0.4.1 conllu-1.3.1 cycler-0.11.0 cymem-2.0.6 docutils-0.17.1 editdistance-0.6.0 fairseq-0.8.0 fastBPE-0.1.0 flaky-3.7.0 flask-2.1.2 flask-cors-3.0.10 ftfy-6.1.1 gevent-21.12.0 greenlet-1.1.2 h5py-3.6.0 imagesize-1.3.0 importlib-metadata-4.11.3 iniconfig-1.1.1 itsdangerous-2.1.2 jmespath-1.0.0 joblib-1.1.0 jsonnet-0.18.0 jsonpickle-2.2.0 kiwisolver-1.4.2 matplotlib-3.3.4 murmurhash-1.0.7 nltk-3.7 numpy-1.15.1 numpydoc-1.3.1 overrides-6.1.0 packaging-21.3 pandas-0.23.4 parsimonious-0.9.0 pillow-9.1.1 plac-0.9.6 pluggy-1.0.0 portalocker-2.0.0 preshed-2.0.1 protobuf-3.20.1 py-1.11.0 pyparsing-3.0.9 pytest-7.1.2 python-dateutil-2.8.2 pytorch-pretrained-bert-0.6.1 pytorch-transformers-1.1.0 pytz-2022.1 regex-2022.4.24 responses-0.20.0 s3transfer-0.5.2 sacrebleu-1.5.1 scikit-learn-1.0.2 scipy-1.3.2 sentencepiece-0.1.96 snowballstemmer-2.2.0 spacy-2.1.8 sphinx-4.5.0 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5 sqlparse-0.4.2 srsly-1.0.5 tensorboardX-2.5 termcolor-1.1.0 thinc-7.0.8 threadpoolctl-3.1.0 tomli-2.0.1 torch-1.0.1 tqdm-4.26.0 typing-extensions-4.2.0 typing-utils-0.1.0 unidecode-1.3.4 wasabi-0.9.1 wcwidth-0.2.5 word2number-1.1 zipp-3.8.0 zope.event-4.5.0 zope.interface-5.4.0

# %%
# %%capture
! wget http://cistern.cis.lmu.de/mlama/mlama1.1.zip
! unzip mlama1.1.zip
! rm mlama1.1.zip

# %%
import sys
sys.path.append('/content/LAMA')
sys.path.append('/content/mlama')

# %%
from mlama import build_encoded_dataset
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
from typing import Text, List, Set, Any, Text, Dict
import os
import json

class MLama(object):
    """docstring for MLama"""

    def __init__(self, path: Text) -> None:
        super(MLama, self).__init__()
        self.path = path
        self.data = {}

    def get_all_languages(self) -> List[Text]:
        # not for all languages templates are available.
        return os.listdir(self.path)

    def get_official_languages(self) -> List[Text]:
        return ["ca", "az", "en", "ar", "uk", "fa", "tr", "it", "el", "ru", "hr", "hi", "sv", "sq", "fr", "ga", "eu", "de", "nl", "et", "he", "es", "bn", "ms", "sr",
                "hy", "ur", "hu", "la", "sl", "cs", "af", "gl", "fi", "ro", "ko", "cy", "th", "be", "id", "pt", "vi", "ka", "ja", "da", "bg", "zh", "pl", "lv", "sk", "lt", "ta", "ceb"]

    def get_relations(self, language) -> List[Text]:
        files = os.listdir(os.path.join(self.path, language))
        return [file.replace(".jsonl", "") for file in files if file != "templates.jsonl"]

    @staticmethod
    def _load_templates(path: Text) -> Dict[Text, Text]:
        templates = {}
        with open(path) as fp:
            for line in fp:
                line = json.loads(line)
                templates[line["relation"]] = line["template"]
        return templates

    @staticmethod
    def _load_triples(path: Text) -> Dict[Text, Dict[Text, Text]]:
        triples = {}
        with open(path) as fp:
            for line in fp:
                line = json.loads(line)
                triples[line["lineid"]] = line
        return triples

    def load(self, languages: List[Text] = [], relations: List[Text] = []) -> None:
        self.data = {}
        if not languages:
            languages = self.get_official_languages()
        for language in languages:
            self.data[language] = {}
            if not relations:
                relations = self.get_relations(language)
            templates = self._load_templates(os.path.join(self.path, language, "templates.jsonl"))
            for relation in relations:
                self.data[language][relation] = {}
                if relation not in templates:
                    print("Template missing for relation {} in language {}.".format(relation, language))
                self.data[language][relation]["template"] = templates.get(relation, "")
                self.data[language][relation]["triples"] = self._load_triples(
                    os.path.join(self.path, language, relation + ".jsonl"))

    @staticmethod
    def is_valid_template(template: Text) -> bool:
        return ("[X]" in template and "[Y]" in template)

    def _fill_templates(self, template: Text, triples: Dict[Text, Dict[Text, Text]], mode: Text) -> Dict[Text, Text]:
        '''
        mode in ["x", "y", "xy"]
        '''
        if not self.is_valid_template(template):
            print("Invalid template: {}".format(template))
            return {}
        else:
            filled_templates = {}
            for triple_id, triple in triples.items():
                filled_templates[triple_id] = template
                if "x" in mode:
                    filled_templates[triple_id] = filled_templates[triple_id].replace("[X]", triple["sub_label"])
                if "y" in mode:
                    filled_templates[triple_id] = filled_templates[triple_id].replace("[Y]", triple["obj_label"])
            return filled_templates

    def fill_all_templates(self, mode: Text):
        for language in self.data:
            for relation in self.data[language]:
                self.data[language][relation]["filled_templates"] = self._fill_templates(
                    self.data[language][relation]["template"], self.data[language][relation]["triples"], mode)

# %%
ml = MLama("./mlama1.1")
ml.load(languages=["cs"])
ml.fill_all_templates("x")
#ml.fill_all_templates("y")
#ml.fill_all_templates("xy")

# %%
ml.data['cs'].keys()
# Out:
# dict_keys(['P264', 'P937', 'P19', 'date_of_birth', 'P176', 'P103', 'P39', 'P449', 'P138', 'P37', 'P131', 'P108', 'place_of_birth', 'P364', 'P31', 'P127', 'P495', 'P136', 'P413', 'P1303', 'P279', 'P159', 'P530', 'P47', 'P1376', 'P106', 'P101', 'P740', 'P361', 'P140', 'P463', 'P1412', 'P17', 'P36', 'P178', 'P30', 'P407', 'P20', 'P527', 'P27', 'P276', 'place_of_death', 'P190', 'P1001'])

# %%
ml.data['cs']['P176']["filled_templates"]
# Out:
# {0: 'Fiat Multipla je produkován [Y].',
#  3: 'Renault Vel Satis je produkován [Y].',
#  5: 'Chevrolet Malibu je produkován [Y].',
#  8: 'Chevrolet Cobalt je produkován [Y].',
#  13: 'Nissan GT-R je produkován [Y].',
#  15: 'Ferrari Enzo je produkován [Y].',
#  17: 'Fiat 126 je produkován [Y].',
#  19: 'Windows 2000 je produkován [Y].',
#  20: 'Fiat Idea je produkován [Y].',
#  21: 'Fiat Ritmo je produkován [Y].',
#  22: 'Triumph Herald je produkován [Y].',
#  23: 'Suzuki SV 650 je produkován [Y].',
#  26: 'Ferrari Daytona je produkován [Y].',
#  27: 'Toyota Supra je produkován [Y].',
#  29: 'Honda CB-750 je produkován [Y].',
#  34: 'Fiat Tipo je produkován [Y].',
#  38: 'Honda ST 1100 Pan European je produkován [Y].',
#  39: 'Airbus A330 je produkován [Y].',
#  40: 'Chevrolet Monte Carlo je produkován [Y].',
#  41: 'BMW řady 5 Gran Turismo je produkován [Y].',
#  43: 'Windows Server 2003 je produkován [Y].',
#  45: 'Audi 80 je produkován [Y].',
#  46: 'Ferrari 212 Inter je produkován [Y].',
#  48: 'Kindle Fire je produkován [Y].',
#  50: 'BMW N54 je produkován [Y].',
#  52: 'Lancia Dedra je produkován [Y].',
#  56: 'Ferrari Dino je produkován [Y].',
#  57: 'Ferrari Dino je produkován [Y].',
#  58: 'BMW řady 7 (F01) je produkován [Y].',
#  60: 'DC-1 je produkován [Y].',
#  62: 'Renault Safrane je produkován [Y].',
#  67: 'Fiat Cinquecento je produkován [Y].',
#  69: 'Nokia 1100 je produkován [Y].',
#  72: 'Bentley Turbo R je produkován [Y].',
#  73: 'Chevrolet Aveo je produkován [Y].',
#  76: 'Nintendo DS Lite je produkován [Y].',
#  78: 'Porsche Panamera je produkován [Y].',
#  82: 'BMW M30 je produkován [Y].',
#  84: 'Pontiac Firebird je produkován [Y].',
#  91: 'Nokia N810 je produkován [Y].',
#  92: 'Ferrari 250 GTO je produkován [Y].',
#  94: 'Lancia 037 je produkován [Y].',
#  95: 'Porsche 911 je produkován [Y].',
#  96: 'Nokia X je produkován [Y].',
#  98: 'Fiat Stilo je produkován [Y].',
#  99: 'Philips CD-i je produkován [Y].',
#  102: 'Honda Civic je produkován [Y].',
#  104: 'BMW řady 7 (E65) je produkován [Y].',
#  107: 'Nokia 5800 je produkován [Y].',
#  110: 'Toyota FJ Cruiser je produkován [Y].',
#  112: 'Audi A8 je produkován [Y].',
#  115: 'Nissan 300ZX je produkován [Y].',
#  121: 'Rolls-Royce Phantom je produkován [Y].',
#  122: 'Renault 12 je produkován [Y].',
#  125: 'Autobianchi A112 je produkován [Y].',
#  127: 'Audi A1 je produkován [Y].',
#  129: 'Redstone je produkován [Y].',
#  131: 'Nokia N8 je produkován [Y].',
#  132: 'Volvo C30 je produkován [Y].',
#  135: 'Ferrari F12berlinetta je produkován [Y].',
#  137: 'Ferrari 458 Italia je produkován [Y].',
#  139: 'BMW Z1 je produkován [Y].',
#  143: 'Ferrari F40 je produkován [Y].',
#  147: 'Fiat 1100 je produkován [Y].',
#  148: 'BMW řady 4 je produkován [Y].',
#  149: 'Honda NSX je produkován [Y].',
#  150: 'BMW řady 3 (E30) je produkován [Y].',
#  153: 'Porsche 356 je produkován [Y].',
#  154: 'LZ 127 Graf Zeppelin je produkován [Y].',
#  155: 'BMW řady 6 (E24) je produkován [Y].',
#  157: 'Ferrari 125 je produkován [Y].',
#  167: 'Renault Twingo je produkován [Y].',
#  168: 'Dodge Charger je produkován [Y].',
#  171: 'Apple II je produkován [Y].',
#  172: 'Honda VFR-1200F je produkován [Y].',
#  173: 'Lexus SC je produkován [Y].',
#  175: 'Honda CX-500 je produkován [Y].',
#  176: 'BMW X5 je produkován [Y].',
#  177: 'Bentley T-series je produkován [Y].',
#  183: 'Renault 4 je produkován [Y].',
#  184: 'Renault 25 je produkován [Y].',
#  185: 'Fiat 500X je produkován [Y].',
#  186: 'Chevrolet Captiva je produkován [Y].',
#  193: 'M6 je produkován [Y].',
#  195: 'BMW M5 je produkován [Y].',
#  196: 'Fiat Barchetta je produkován [Y].',
#  201: 'Fairchild C-119 Flying Boxcar je produkován [Y].',
#  204: 'Hepcidin je produkován [Y].',
#  205: 'Toyota Auris je produkován [Y].',
#  206: 'BMW E9 je produkován [Y].',
#  207: 'BMW M70 je produkován [Y].',
#  208: 'Socket 775 je produkován [Y].',
#  210: 'Boeing 777 je produkován [Y].',
#  213: 'IBM Personal Computer je produkován [Y].',
#  217: 'Windows 7 je produkován [Y].',
#  219: 'Lancia Thema je produkován [Y].',
#  221: 'Nintendo 3DS je produkován [Y].',
#  225: 'BMW i8 je produkován [Y].',
#  226: 'Porsche 996 je produkován [Y].',
#  227: 'Bentley Arnage je produkován [Y].',
#  228: 'Fully Integrated Robotised Engine je produkován [Y].',
#  229: 'Osmibitové počítače Atari je produkován [Y].',
#  230: 'Nokia Lumia 925 je produkován [Y].',
#  237: 'BMW X1 je produkován [Y].',
#  238: 'BMW 328 je produkován [Y].',
#  240: 'Renault 19 je produkován [Y].',
#  242: 'Daewoo Kalos je produkován [Y].',
#  243: 'Nissan Sunny je produkován [Y].',
#  244: 'BMW řady 3 (E36) je produkován [Y].',
#  246: 'Audi Q5 je produkován [Y].',
#  247: 'BMW 303 je produkován [Y].',
#  248: 'Ferrari 166 S je produkován [Y].',
#  251: 'Lancia Lybra je produkován [Y].',
#  252: 'Ferrari FF je produkován [Y].',
#  255: 'Audi e-tron je produkován [Y].',
#  257: 'Renault Dauphine je produkován [Y].',
#  262: 'Fiat 124 Sport Spider je produkován [Y].',
#  265: 'Chevrolet Equinox je produkován [Y].',
#  267: 'Toyota RAV4 je produkován [Y].',
#  268: 'Nissan Qashqai je produkován [Y].',
#  269: 'Honda VFR-800 je produkován [Y].',
#  275: 'iPhone je produkován [Y].',
#  276: 'iPhone 5 je produkován [Y].',
#  277: 'Fiat Linea je produkován [Y].',
#  279: 'Chevrolet Chevelle je produkován [Y].',
#  280: 'McLaren MP4-20 je produkován [Y].',
#  285: 'Porsche 944 je produkován [Y].',
#  286: 'Intel 8008 je produkován [Y].',
#  288: 'Audi RS4 je produkován [Y].',
#  289: 'Renault 4CV je produkován [Y].',
#  293: 'BMW 003 je produkován [Y].',
#  299: 'Windows Phone 8 je produkován [Y].',
#  301: 'Nokia E71 je produkován [Y].',
#  303: 'Chevrolet Corvair je produkován [Y].',
#  305: 'Fiat Croma je produkován [Y].',
#  306: 'Audi A5 je produkován [Y].',
#  311: 'Daihatsu Terios je produkován [Y].',
#  317: 'BMW Z3 je produkován [Y].',
#  318: 'Airbus A380 je produkován [Y].',
#  319: 'Nokia N900 je produkován [Y].',
#  325: 'Fiat 850 je produkován [Y].',
#  326: 'Alpine A108 je produkován [Y].',
#  333: 'Fiat Panda je produkován [Y].',
#  334: 'Jeep Grand Cherokee je produkován [Y].',
#  336: 'Porsche 959 je produkován [Y].',
#  339: 'iPhone 4S je produkován [Y].',
#  341: 'Renault Avantime je produkován [Y].',
#  343: 'BMW 503 je produkován [Y].',
#  345: 'Volvo S80 je produkován [Y].',
#  346: 'Nintendo DS je produkován [Y].',
#  347: 'BMW M6 je produkován [Y].',
#  348: 'Fiat Regata je produkován [Y].',
#  349: 'Audi Q7 je produkován [Y].',
#  352: 'Nissan 100NX je produkován [Y].',
#  354: 'Boeing B-17 Flying Fortress je produkován [Y].',
#  358: 'Audi TT je produkován [Y].',
#  364: 'Porsche 997 je produkován [Y].',
#  365: 'Fiat Bravo je produkován [Y].',
#  366: 'Toyota MR2 je produkován [Y].',
#  367: 'Micubiši F1M je produkován [Y].',
#  368: 'Apple I je produkován [Y].',
#  370: 'McDonnell Douglas DC-9 je produkován [Y].',
#  372: 'iPod Classic je produkován [Y].',
#  377: 'Honda CR-X je produkován [Y].',
#  384: 'Ferrari 125 S je produkován [Y].',
#  387: 'Toyota Corolla AE86 je produkován [Y].',
#  390: 'BMW Z4 (E85) je produkován [Y].',
#  392: 'BMW řady 3 (E46) je produkován [Y].',
#  393: 'BMW řady 5 (E39) je produkován [Y].',
#  394: 'Renault 16 je produkován [Y].',
#  397: 'Xbox je produkován [Y].',
#  399: 'Ferrari Mondial je produkován [Y].',
#  401: 'Triumph TR7 je produkován [Y].',
#  402: 'Boeing RC-135 je produkován [Y].',
#  403: 'Toyota Corolla je produkován [Y].',
#  406: 'Nokia Lumia 1020 je produkován [Y].',
#  407: 'iPhone 3GS je produkován [Y].',
#  410: 'Honda Legend je produkován [Y].',
#  412: 'Suzuki Ignis je produkován [Y].',
#  415: 'Nokia N73 je produkován [Y].',
#  417: 'Lancia Y10 je produkován [Y].',
#  419: 'Ferrari FXX je produkován [Y].',
#  420: 'Fiat Marea je produkován [Y].',
#  423: 'BMW řady 1 (E87) je produkován [Y].',
#  424: 'Chevrolet HHR je produkován [Y].',
#  426: 'Audi V8 je produkován [Y].',
#  427: 'iPod je produkován [Y].',
#  432: 'Audi RS2 je produkován [Y].',
#  439: 'Nokia C7 je produkován [Y].',
#  441: 'BMW M52 je produkován [Y].',
#  446: 'Renault 21 je produkován [Y].',
#  449: 'BMW X3 je produkován [Y].',
#  450: 'BMW řady 3 je produkován [Y].',
#  453: 'BMW X5 (E53) je produkován [Y].',
#  454: 'Alfa Romeo 164 je produkován [Y].',
#  458: 'Boeing B-29 Superfortress je produkován [Y].',
#  459: 'Lancia Ypsilon je produkován [Y].',
#  462: 'Audi S5 je produkován [Y].',
#  463: 'MacBook Air je produkován [Y].',
#  464: 'Alfa Romeo 75 je produkován [Y].',
#  465: 'Datsun 240Z je produkován [Y].',
#  466: 'Douglas DC-5 je produkován [Y].',
#  467: 'iPod shuffle je produkován [Y].',
#  469: 'Chevrolet Orlando je produkován [Y].',
#  472: 'Alfa Romeo Alfasud je produkován [Y].',
#  478: 'Renault Koleos je produkován [Y].',
#  479: 'Audi 100 je produkován [Y].',
#  480: 'Fiat Duna je produkován [Y].',
#  481: 'Audi S4 je produkován [Y].',
#  484: 'AGM-86 je produkován [Y].',
#  485: 'Alfa Romeo Brera je produkován [Y].',
#  488: 'BMW i01 je produkován [Y].',
#  491: 'Fairchild C-82 Packet je produkován [Y].',
#  494: 'Alpine A106 je produkován [Y].',
#  495: 'Honda VT 125C Shadow je produkován [Y].',
#  498: 'Suzuki B-King je produkován [Y].',
#  499: 'Airbus A330neo je produkován [Y].',
#  500: 'BMW IIIa je produkován [Y].',
#  503: 'Lexus ES je produkován [Y].',
#  504: 'Audi A2 je produkován [Y].',
#  505: 'BMW řady 1 (F20) je produkován [Y].',
#  506: 'Renault 8 je produkován [Y].',
#  510: 'Nintendo Entertainment System je produkován [Y].',
#  515: 'Dodge Challenger je produkován [Y].',
#  521: 'Honda Insight je produkován [Y].',
#  523: 'Nissan Almera je produkován [Y].',
#  525: 'BMW R32 je produkován [Y].',
#  528: 'Fiat 125 je produkován [Y].',
#  529: 'Honda Prelude je produkován [Y].',
#  530: 'IPad Mini je produkován [Y].',
#  531: 'Fiat 132/Argenta je produkován [Y].',
#  533: 'Ferrari 575M Maranello je produkován [Y].',
#  534: 'MacBook Pro je produkován [Y].',
#  535: 'Nissan 370Z je produkován [Y].',
#  540: 'Boeing EA-18G Growler je produkován [Y].',
#  541: 'Chevrolet Venture je produkován [Y].',
#  542: 'Porsche Cayenne je produkován [Y].',
#  544: 'Toyota Celica je produkován [Y].',
#  545: 'Alfa Romeo 155 je produkován [Y].',
#  550: 'Fiat 128 je produkován [Y].',
#  551: 'Nissan Silvia je produkován [Y].',
#  552: 'Nissan Skyline je produkován [Y].',
#  553: 'Lexus RX je produkován [Y].',
#  555: 'iPad je produkován [Y].',
#  556: 'Alfa Romeo Montreal je produkován [Y].',
#  558: 'Boeing Monomail je produkován [Y].',
#  563: 'Boeing C-135 Stratolifter je produkován [Y].',
#  572: 'BMW M50 je produkován [Y].',
#  573: 'Douglas DC-4 je produkován [Y].',
#  576: 'Nokia N82 je produkován [Y].',
#  578: 'Nissan Patrol je produkován [Y].',
#  579: 'Nokia N80 je produkován [Y].',
#  583: 'Toyota Prius je produkován [Y].',
#  587: 'Toyota Aygo je produkován [Y].',
#  589: 'McLaren MP4/25 je produkován [Y].',
#  592: 'Fiat 130 je produkován [Y].',
#  593: 'CIM-10 Bomarc je produkován [Y].',
#  596: 'BMW Z4 je produkován [Y].',
#  597: 'Airbus A300 je produkován [Y].',
#  598: 'Fiat 1400 a 1900 je produkován [Y].',
#  600: 'Porsche 918 Spyder je produkován [Y].',
#  603: 'Audi Q3 je produkován [Y].',
#  605: 'Honda CB-900F je produkován [Y].',
#  606: 'Jeep Wrangler je produkován [Y].',
#  607: 'BMW M3 je produkován [Y].',
#  609: 'LaFerrari je produkován [Y].',
#  610: 'Boeing 367-80 je produkován [Y].',
#  613: 'Dacia Sandero je produkován [Y].',
#  614: 'BMW řady 3 (E90) je produkován [Y].',
#  616: 'iPhone je produkován [Y].',
#  617: 'Nissan Navara je produkován [Y].',
#  618: 'Suzuki GSX-R 1300 Hayabusa je produkován [Y].',
#  624: 'Suzuki Intruder je produkován [Y].',
#  627: 'Dacia Duster je produkován [Y].',
#  628: 'volvo850 je produkován [Y].',
#  629: 'Fiat 127 je produkován [Y].',
#  630: 'Ferrari 365 je produkován [Y].',
#  631: 'Chevrolet Spark je produkován [Y].',
#  633: 'Chevrolet Express je produkován [Y].',
#  634: 'Ferrari 550 Maranello je produkován [Y].',
#  635: 'PGM-19 Jupiter je produkován [Y].',
#  636: 'Sapsan je produkován [Y].',
#  641: 'Honda CBR-600F je produkován [Y].',
#  646: 'Fiat Fiorino je produkován [Y].',
#  650: 'Fiat 124 je produkován [Y].',
#  651: 'Fiat 500 je produkován [Y].',
#  656: 'Isetta je produkován [Y].',
#  660: 'Toyota Starlet je produkován [Y].',
#  661: 'Nokia 3310 je produkován [Y].',
#  662: 'Mikasa je produkován [Y].',
#  663: 'Triumph TR6 je produkován [Y].',
#  667: 'BMW M54 je produkován [Y].',
#  669: 'Lancia Gamma je produkován [Y].',
#  670: 'Nissan X-Trail je produkován [Y].',
#  671: 'Fiat Siena je produkován [Y].',
#  672: 'Porsche 911 GT1 je produkován [Y].',
#  674: 'Audi Quattro je produkován [Y].',
#  677: 'Ferrari 599 GTB Fiorano je produkován [Y].',
#  679: 'Renault 18 je produkován [Y].',
#  680: 'Lancia Musa je produkován [Y].',
#  682: 'Game Boy Advance je produkován [Y].',
#  683: 'Audi R8 je produkován [Y].',
#  689: 'Chevrolet Delray je produkován [Y].',
#  691: 'Chevrolet TrailBlazer je produkován [Y].',
#  693: 'Chevrolet El Camino je produkován [Y].',
#  698: 'BMW M1 je produkován [Y].',
#  700: 'Chevrolet Suburban je produkován [Y].',
#  701: 'Nokia N9 je produkován [Y].',
#  702: 'BMW M60 je produkován [Y].',
#  703: 'Honda CRF series je produkován [Y].',
#  705: 'Douglas F3D Skyknight je produkován [Y].',
#  706: 'Game & Watch je produkován [Y].',
#  708: 'Volvo V70 je produkován [Y].',
#  709: 'Ferrari 612 Scaglietti je produkován [Y].',
#  710: 'Sega Game Gear je produkován [Y].',
#  711: 'BMW řady 6 je produkován [Y].',
#  712: 'Airbus A320 je produkován [Y].',
#  714: 'Lexus IS je produkován [Y].',
#  716: 'Honda ST 1300 Pan European je produkován [Y].',
#  717: 'Renault Captur je produkován [Y].',
#  719: 'Daewoo Damas je produkován [Y].',
#  721: 'Ferrari F430 Challenge je produkován [Y].',
#  727: 'Nissan Pulsar je produkován [Y].',
#  728: 'Chevrolet Caprice je produkován [Y].',
#  736: 'Nokia N800 je produkován [Y].',
#  737: 'BMW řady 7 (E38) je produkován [Y].',
#  742: 'Windows Vista je produkován [Y].',
#  747: 'Triumph Dolomite je produkován [Y].',
#  752: 'Chevrolet Trax je produkován [Y].',
#  754: 'Renault Juvaquatre je produkován [Y].',
#  755: 'Fiat 2300 je produkován [Y].',
#  757: 'anděl je produkován [Y].',
#  759: 'Nokia Lumia 1520 je produkován [Y].',
#  761: 'Chevrolet Corvette C2 je produkován [Y].',
#  762: 'Renault 5 je produkován [Y].',
#  763: 'Super Nintendo Entertainment System je produkován [Y].',
#  765: 'ICE TD je produkován [Y].',
#  767: 'Renault Clio je produkován [Y].',
#  769: 'Boeing KC-46 Pegasus je produkován [Y].',
#  771: 'Ferrari F355 je produkován [Y].',
#  773: 'Mac Pro je produkován [Y].',
#  774: 'Peugeot 107 je produkován [Y].',
#  775: 'Ferrari 288 GTO je produkován [Y].',
#  776: 'Nokia N70 je produkován [Y].',
#  778: 'BMW řady 7 (E23) je produkován [Y].',
#  781: 'Ferrari California je produkován [Y].',
#  782: 'Fiat Tempra je produkován [Y].',
#  786: 'Vickers Medium Mark I je produkován [Y].',
#  789: 'MCS-48 je produkován [Y].',
#  790: 'Chevrolet Uplander je produkován [Y].',
#  792: 'Renault 5 Turbo je produkován [Y].',
#  793: 'Toyota Carina je produkován [Y].',
#  795: 'BMW Z4 (E89) je produkován [Y].',
#  802: 'Ferrari D246 je produkován [Y].',
#  804: 'Fiat Palio je produkován [Y].',
#  807: 'BMW 326 je produkován [Y].',
#  808: 'Volvo XC90 je produkován [Y].',
#  816: 'Renault Espace je produkován [Y].',
#  818: 'Airbus A350 je produkován [Y].',
#  821: 'Chevrolet Chevette je produkován [Y].',
#  823: 'Audi A4 je produkován [Y].',
#  824: 'Boeing B-47 Stratojet je produkován [Y].',
#  825: 'Ferrari 250 GTO je produkován [Y].',
#  826: 'BMW M62 je produkován [Y].',
#  827: 'Airbus Beluga je produkován [Y].',
#  831: 'Volvo C70 je produkován [Y].',
#  836: 'Airbus A310 je produkován [Y].',
#  842: 'Toyota 2000GT je produkován [Y].',
#  843: 'ICE 3 je produkován [Y].',
#  844: 'Suzuki GSX-R je produkován [Y].',
#  845: 'Renault Kangoo je produkován [Y].',
#  846: 'LGM-30 Minuteman je produkován [Y].',
#  850: 'BMW 801 je produkován [Y].',
#  852: 'Airbus A340 je produkován [Y].',
#  853: 'Nintendo 2DS je produkován [Y].',
#  855: 'iPod touch je produkován [Y].',
#  856: 'Nissan Primera je produkován [Y].',
#  858: 'Toyota Avensis je produkován [Y].',
#  864: 'Honda CB 550 Four je produkován [Y].',
#  865: 'BMW X6 je produkován [Y].',
#  866: 'Chevrolet Bel Air je produkován [Y].',
#  867: 'Porsche 914 je produkován [Y].',
#  868: 'Intel 8085 je produkován [Y].',
#  869: 'BMW 700 je produkován [Y].',
#  874: 'Renault Trafic je produkován [Y].',
#  876: 'BMW řady 5 je produkován [Y].',
#  877: 'Ferrari 158 je produkován [Y].',
#  879: 'Renault Estafette je produkován [Y].',
#  882: 'Chevrolet Tahoe je produkován [Y].',
#  885: 'Audi A7 je produkován [Y].',
#  886: 'Renault Fuego je produkován [Y].',
#  888: 'Chevrolet Celebrity je produkován [Y].',
#  889: 'Lexus LFA je produkován [Y].',
#  892: 'Fiat Uno je produkován [Y].',
#  893: 'muscle car je produkován [Y].',
#  897: 'BMW N52 je produkován [Y].',
#  899: 'Nissan Cherry je produkován [Y].',
#  900: 'Ferrari 348 je produkován [Y].',
#  902: 'BMW řady 7 je produkován [Y].',
#  904: 'Douglas DC-3 je produkován [Y].',
#  905: 'Renault R26 je produkován [Y].',
#  907: 'Alfa Romeo MiTo je produkován [Y].',
#  909: 'BMW E3 je produkován [Y].',
#  910: 'Vickers je produkován [Y].',
#  912: 'Dodge WC je produkován [Y].',
#  913: 'BMW M40 je produkován [Y].',
#  914: 'Honda S2000 je produkován [Y].',
#  915: 'Ferrari F430 je produkován [Y].',
#  917: 'Honda CBR 1100 XX Super Blackbird je produkován [Y].',
#  919: 'Nokia Lumia je produkován [Y].',
#  920: 'Xeon je produkován [Y].',
#  922: 'Dodge Polara je produkován [Y].',
#  923: 'Wii U je produkován [Y].',
#  925: 'Lancia Flavia je produkován [Y].',
#  926: 'Fairchild A-10 Thunderbolt II je produkován [Y].',
#  928: 'Audi F103 je produkován [Y].',
#  929: 'Chevrolet Silverado je produkován [Y].',
#  930: 'BMW 501 je produkován [Y].',
#  931: 'Honda CR-V je produkován [Y].',
#  935: 'Windows Phone 8.1 je produkován [Y].',
#  939: 'BMW S65 je produkován [Y].',
#  941: 'Porsche Carrera GT je produkován [Y].',
#  944: 'Nokia Lumia 520 je produkován [Y].',
#  945: 'Airbus A320neo je produkován [Y].',
#  946: 'Model M je produkován [Y].',
#  947: 'Chevrolet Impala je produkován [Y].',
#  951: 'Fiat Albea je produkován [Y].',
#  954: 'Lexus NX je produkován [Y].',
#  957: 'Chevrolet SSR je produkován [Y].',
#  958: 'Dodge Viper je produkován [Y].',
#  960: 'Fiat Strada je produkován [Y].',
#  963: 'Sega Master System je produkován [Y].',
#  964: 'Douglas X-3 je produkován [Y].',
#  965: 'Honda Integra je produkován [Y].',
#  969: 'Renault Laguna je produkován [Y].',
#  971: 'Audi RS6 je produkován [Y].',
#  972: 'Mini Countryman je produkován [Y].',
#  980: 'Fiat Grande Punto je produkován [Y].'}

# %%
open('./cs-templates.json', 'w').write(json.dumps(ml.data))
# Out:
# 3629054
